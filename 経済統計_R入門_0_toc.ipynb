# %% [markdown]
# # **R入門（目次）**
#
# **はじめに：**<br>
# 最初に「colaboratoryで始めるR.pdf」を読んで、Colab（Google Colaboratory）を準備してから以下を読んでください。
# <br>
# <br>
#
#
# ---
#
#
#
# **このノートブックについて**<br>
# このColabのノートブックは「R入門」の目次です。
# <br>
# *   [R入門（その1）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_R入門_1_basic.ipynb)：Rの第一歩
# *   [R入門（その2）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_R入門_2_lm.ipynb)：Rで単回帰
# *   [R入門（その3）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_R入門_3_plot.ipynb)：Rを使ったグラフ作成
# *   [R入門（その4）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_R入門_4_var.ipynb)：Rで平均・分散・標準偏差
# *   [R入門（その5）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_R入門_5_for.ipynb)：Rの制御構文（ifとfor）
# *   [R入門（その6）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_R入門_6_func.ipynb)：Rで関数を作る
# *   [R入門（その7）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_R入門_7_lm.ipynb)：Rで重回帰
# *   [R入門（その8）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_R入門_8_dummy.ipynb)：Rでダミー変数
# *   リスト項目
#
#
# > 注：このノートブックは駒澤大学経済学部で開講している「経済統計a/b」で「Excel以外の手法を学ぶ意欲がある履修生向け」に統計解析ソフトRの最低限の知識を解説する補助資料です。
#
# [参考]
# *   [Introduction to Econometrics with R](https://www.econometrics-with-r.org/)
# *   リスト項目
