# %% [markdown]
# # **R入門（目次）**
#
# ---
#
#
#
# **このノートブックについて**<br>
# このColabのノートブックは「R入門」の目次です。
# <br>
# *   [R入門（その1）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計a_R入門_1_basic.ipynb)：Rの第一歩
# *   [R入門（その2）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計a_R入門_2_lm.ipynb)：Rを使った単回帰
# *   [R入門（その3）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計a_R入門_3_plot.ipynb)：Rを使ったグラフ作成
# *   [R入門（その4）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計a_R入門_4_for.ipynb)：Rの制御構文（forとwhile）
# *   [R入門（その5）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計a_R入門_5_func.ipynb)：Rで関数を作る
#
#
#
# > 注：このノートブックは駒澤大学経済学部で開講している「経済統計a/b」で「Excel以外の手法を学ぶ意欲がある履修生向け」に統計解析ソフトRの最低限の知識を解説する補助資料です。
