# %% [markdown]
# **Pandasでデータフレーム**
#
# このColabのノートブック「Python入門（その6）」では「Pythonでデータフレームの使い方」を解説します。
#
# > 注：このノートブックは駒澤大学経済学部で開講している「経済統計a/b」で「Excel以外の手法を学ぶ意欲がある履修生向け」に**最低限の知識**だけ解説する**補助資料**です

# %%
# 最初に重要な呪文を唱えます。
# 初心者の間は何をしているのかわからなくても構いません。
import pandas as pd

# %% [markdown]
# データ分析（回帰分析）を使うため、データ（CSVファイル）をインターネットから読み込みます。ここではread_csvというメソッドを使ってインターネット上にあるデータをPythonに読み込み、ice_dfという名前で保存します。

# %%
ice_df = pd.read_csv("https://www.dropbox.com/s/2ky13qi387j8b05/kion_iceCream.csv?raw=1",encoding="utf_8")
# Out:
#         年月    気温  アイスクリーム支出金額
# 0  2005年4月  15.1          541
# 1  2005年5月  17.7          666
# 2  2005年6月  23.2          801
# 3  2005年7月  25.6         1033
# 4  2005年8月  28.1         1175

# %% [markdown]
# これでice_dfという変数にデータが入力されました。このicd_dfにどのようなデータが入っているかを確認してみましょう。head()、tail()などのメソッドを使います。すでに解説しましたが、head()は上から5行を表示するメソッドです。

# %%
ice_df.head()
# Out:
#         年月    気温  アイスクリーム支出金額
# 0  2005年4月  15.1          541
# 1  2005年5月  17.7          666
# 2  2005年6月  23.2          801
# 3  2005年7月  25.6         1033
# 4  2005年8月  28.1         1175

# %% [markdown]
# 次にtail()を使ってみましょう。tail()は下から5行を表示する関数です。

# %%
ice_df.tail()
# Out:
#           年月    気温  アイスクリーム支出金額
# 55  2009年11月  13.5          402
# 56  2009年12月   9.0          440
# 57   2010年1月   7.0          362
# 58   2010年2月   6.5          305
# 59   2010年3月   9.1          383

# %% [markdown]
# **データフレームとは？**
#
# ところでExcelなどの表計算ソフトで以下のような表を見たことがある人は多いのではないでしょうか？このような表（になるようなデータ）をPythonではデータフレーム（data frame）といいます。見方は以下の図のとおりです（Excelに慣れた人にとってはおなじみですね）。
#
#
# > 下記のデータは総務省の家計調査と気象庁の東京都の平均気温（月次）から

# %% [markdown]
# ![アイス支出と気温.png](data:image/png;base64,...)

# %% [markdown]
# データフレームも（基本的には）Excelの表と同じで、列名（項目の名前）と実際のデータから構成されます。データフレームでは、数値だけでなく、文字（文字列）も入れられます（Excelと同じですね）。
#
# Pythonでデータ分析をするときデータフレームは非常によく使うため、名前だけでも覚えておいてください。
