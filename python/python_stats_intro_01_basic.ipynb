# %% [markdown]
# #**Python入門（その1）：Pythonの第一歩**
#
# このColabのノートブック「Python入門（その1）」では「Pythonの第一歩」を解説します。
#
# このノートブックは、[colaboratoryで始めるpython](https://github.com/koiti-yano/colab/blob/main/colaboratoryで始めるpython.pdf)をすでに読んでいることを前提に話を進めます。
#
# > 注：このノートブックは駒澤大学経済学部で開講している「経済統計a/b」で「Excel以外の手法を学ぶ意欲がある履修生向け」に**最低限の知識**だけ解説する**補助資料**です。
# <br>
# 補足：最小限のことしか解説しないので、詳しく知りたい人は別の書籍・サイト等を参照してください。

# %% [markdown]
# **Pythonのプログラムを始める前に知ってほしいこと**<br>
# 1. プログラム（正確にはスクリプト）は基本的に**上から下へ順番に実行**されます。→Colabのプログラムは上から順番に実行してください。
# 1. プログラム（スクリプト）は皆さんが書いたとおりに動きます。「あれ？思ったような実行結果にならないな」という場合、皆さんがなにかミスをしています（たとえば、カンマ,とピリオド.を書き間違えるなど）。
# 1. プログラム（スクリプト）はいきなり入力するのではなく、最初に「この手順で（自分がやりたいことが）きちんと実行されるか」を考えましょう。
# 1. Pythonの仕様（ルール）はとても多いので、一度に覚えることはできません。最初は必要最小限だけ学び、実際に使っていく中で徐々に知識を増やしましょう。焦る必要はありません。
#
# **基本用語「文・式・条件式」**
#
# *  文とは、コンピューターへの命令です。たとえば、プログラムに「print("Hello!")」という文があったら、「Helloと表示（正確には出力）せよ」とコンピューターに命令しています。プログラムは文を複数並べたもので、基本的には上から順番に実行されます
# *  式とは、コンピューターへ「計算せよ」と命令する文です。たとえば、プログラムに「1+1」とあったら、「1+1を計算せよ」とコンピューターに命令しています
# *  条件式とは、「真（正しい）」もしくは「偽（正しくない）」が返ってくるような式です。たとえば、「1<2」と書いた場合、「1より2のほうが大きいのは真」ですから「真」が帰ってきます。
#
# 文・式・条件式は言葉で説明すると難しいと感じるかもしれませんが、実際のプログラムを見るとそれほど難しくはありません。

# %% [markdown]
# **四則演算から始めよう**<br>最初に四則演算から始めましょう。足し算は+、引き算は-、掛け算は*、割り算は/を使います。なお、入力する数字や記号はすべて半角英数字です。計算の結果を見ると整数だけでなく、小数や負の数（マイナス）なども使えることがわかります。

# %%
1 + 3
# Out:
# 4

# %%
1 - 2
# Out:
# -1

# %%
1.3 * 2
# Out:
# 2.6

# %%
5 / 2
# Out:
# 2.5

# %% [markdown]
# 次は少し難しいですが、べき乗です。たとえば「2の3乗は8」です。**を使います。（Rの場合は、^を使い、2^3と書きます。Pythonと違うため、RとPython両方を使う人は気をつけましょう。）

# %%
2**3
# Out:
# 8

# %% [markdown]
# **変数への代入をしよう**<br>次に変数への代入を学びましょう。「変数？代入？」と思う人は早速やってみましょう！

# %%
a = 1

# %% [markdown]
# Pythonでは「=」は代入することを意味します（数学の表記と異なることに注意してください）。
# <br>
# 実際に変数aに1が入っているかどうかを確認してみましょう。単にaと入力して実行すれば出力されます。

# %%
a
# Out:
# 1

# %% [markdown]
# それ以外の方法としてはprint()という関数を使うやり方です。関数については後で説明しますので、とりあえずやってみましょう。

# %%
print(a)
# Out:
# 1

# %% [markdown]
# 変数aに1を代入し、次に変数bに2を代入し、最後にa+bを計算してみましょう。図示すると以下のようなイメージになります。

# %% [markdown]
# ![Python：図で理解する代入.png](data:image/png;base64,...)

# %% [markdown]
# 早速、やってみましょう。

# %%
# まとめて書いてみましょう。
a = 1
b = 2
a + b
# Out:
# 3

# %% [markdown]
# **コメントを入れよう**
# <br>
# プログラムの中に「覚書や注釈」を書き込むことをコメントといいます。最初は「そんなことして何の役に立つのか？」と疑問に思うかもしれませんが、プログラムの中に適切にコメントを入力しておくことはとても重要です（コメントが必要な理由としては、「あとでプログラムを読む人のためになる」が挙げられます。）。
#
# *  標語：ぜひ積極的にコメントを活用しましょう！
#
# それではコメントはどうすれば書けるのでしょうか？原則は以下の2つです。
#
# 1.   1行だけのコメントでは#（半角のシャープ）を使う
# 2.   複数行のコメントは"""（二重引用符3つで始まり、二重引用符3つで終わる）
#
# 言葉で説明するよりも実例を見たほうが早いかもしれません。

# %%
# 「#（半角のシャープ）」を入力するとその右側はすべてコメントになります。
# コメントにはプログラムに関する覚書やマニュアルなどを入力します。

# %%
"""
ここにコメントを書きます。二重引用符3つで始まり、二重引用符3つで終わりです。
複数行に渡るコメントを書くときに便利です。
"""
# Out:
# '\nここにコメントを書きます。二重引用符3つで始まり、二重引用符3つで終わりです。\n複数行に渡るコメントを書くときに便利です。\n'

# %% [markdown]
# **TrueとFalseを覚えよう！**
# <br>
# 最初は「何に役立つのかわからない！」と思うかもしれませんが、<br>Pythonでは「真をTrue」、「偽をFalse」と表します。（「真と偽なんて哲学の用語みたいで難しい」と思う人がいるかもしれません。真＝正しい、偽＝間違っているくらいに思ってください。）
#
# たとえば、「x = 11, y = 11, z = 22」と代入したとき、
#
# - 「x = y」は真（xには11、yにも11が入っているので、x=yは正しい。つまり真）
# - 「x = z」は偽（xには11、zには22が入っているので、x=zは間違い、つまり偽）
#
# ただし、「x = y（数学での表記）」のように2つの値が等しいことを表すとき、**Pythonでは==を使います（←ここ重要）。**

# %%
x = 11 # 変数xに11を代入します
y = 11 # 変数yに11を代入します
z = 22 # 変数zに22を代入します

# %%
x == y # 変数xと変数yが等しいかどうか確認します。
# Out:
# True

# %% [markdown]
# 変数xと変数yはどちらにも11が入っていて、等しい（==）ため、True（真）と表示されます。それでは変数xと変数zが等しいかを確認しましょう。

# %%
x == z
# Out:
# False

# %% [markdown]
# 変数xには11、変数zには22が入っていて、等しくないため、False（偽）と表示されます。
#
#
# > ==, <, > <=, >= については第6回のfor, ifのときに解説します。

# %% [markdown]
# **リストを作ろう**<br>次にリストを作りましょう。リストは数（スカラー）等の組み合わせから作ることができます。
# <br>
# 作り方は大括弧[]とカンマ,で数（スカラー）の組み合わせを作るだけです。リストの名前はnumlistのように複数の半角英数字を組み合わせて作ることができます。

# %%
numlist = [1, -2.1, 5.6, 4]
numlist
# Out:
# [1, -2.1, 5.6, 4]

# %% [markdown]
# 一つ上で作ったリストnumlistから要素（数字）を取り出してみましょう。numlistの中で左から1番目の要素（数）は1、左からから3番目の要素は5.6です。
#
# ここで重要なポイント：Pythonでインデックスは0から始まるので、左から1番目の要素（数）を取り出すときインデックスは0、左から3番目の要素（数）を取り出すときインデックスは2になります。また、取り出すときには[]を使います。

# %%
numlist[0]
# Out:
# 1

# %%
numlist[2]
# Out:
# 5.6

# %% [markdown]
# 「Pythonでインデックスは0から始まる」というのは最初は戸惑う人がいるかももしれませんが、慣れれば難しくはありません。

# %% [markdown]
# **文字列を使う**
# <br>
# 文字列（文字や文章）を変数にすることもできます。この場合、二重引用符""もしくは一重引用符''を使います。

# %%
mojiretsu = "今日の天気は晴れです"
mojiretsu
# Out:
# '今日の天気は晴れです'

# %% [markdown]
# mojiretsuという変数の中に「今日の天気は晴れです」と文字列（文章）が入っていることがわかります。文字列のリストを作ることもできます。

# %%
mojilist = ["今日の天気は晴れです", "昨日の天気は雨でした", "明日の天気は予報では雪です"]
mojilist
# Out:
# ['今日の天気は晴れです', '昨日の天気は雨でした', '明日の天気は予報では雪です']

# %% [markdown]
# 文字列のリストの2番目の要素は"昨日の天気は雨でした"です。それを取り出してみましょう。この場合も[]を使います。

# %%
mojilist[1]
# Out:
# '昨日の天気は雨でした'

# %% [markdown]
# **文字列に関するちょっと寄り道**
# <br>
# ここで少し寄り道してみましょう。Pythonには文字列に数字を掛けたり、足し算をしたりするという面白い機能があります。はじめて聞く人は「なんだ、それは？」と思うかもしれません。実際に試してみましょう。
# <br>
# 最初にmojiretsuを3倍にしてみましょう。続いて、文字列の足し算もやってみます。

# %%
"本日は晴天なり" * 3
# Out:
# '本日は晴天なり本日は晴天なり本日は晴天なり'

# %%
"本日は晴天ですが、" + "明日は雨になります"
# Out:
# '本日は晴天ですが、明日は雨になります'

# %% [markdown]
# 面白い機能ですね！

# %% [markdown]
# **関数（すでに組み込まれた関数）を使う**
# <br>
# 続いて関数という機能を使ってみましょう。たとえば、文字列の文字数を数える場合を考えましょう。Pythonではlen()という関数を使います（半角文字のlenと括弧()を使います）。また、len()の括弧内に入る変数を引数といいます。
# <br>
# 最初から組み込まれているので組み込み関数などと呼ばれます。組み込み関数は多いので、最初から全部覚える必要はありません。

# %%
len(mojiretsu)
# Out:
# 10

# %% [markdown]
# 「今日の天気は晴れです」は10文字ですから、正しく10と表示されています。

# %% [markdown]
# それ以外にも平方根を計算するsqrt()という関数などもあります。4の平方根は2ですね。実際にやってみましょう。

# %% [markdown]
# **モジュールのインポート**
# <br>
# Pythonでは多くの便利な機能がモジュールという単位でまとめられています。モジュールはimportというコマンドでPythonに読み込んでから使います。
# <br>
# たとえば数学に関する便利な機能の多くはmathというモジュールに含まれています。たとえば平方根を計算するsqrt()という関数はmathに含まれています（平方根を英語でsquare rootといい、sqrt()という関数名は英語に由来します）。なお、モジュールに含まれる関数はメソッドといいます
#
# たとえば、4の平方根は2です。つまり、
# $$\sqrt{4}=2$$
# ですね。実際にそうなるのか試してみましょう。

# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# ところでメソッドsqrt()を使うとき、「math.sqrt(4)」と入力してもいいのですが、もう少し短く書きたいという人もいるかもしれません。その場合、asというコマンドを使って短くすることができます。mathをmtと短くして使ってみましょう。
# <br>
# 以下のように書きます。

# %%
import math as mt
mt.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# Pythonには、math以外にもデータの取扱が便利になるpandasや数値計算に関するモジュールnumpy、回帰分析のstatsmodels.api、機械学習のscikit-learn(sklearn)など多くの役立つモジュールがあります。たとえば、numpyを使って、0から5までの数字（整数）の列を作ってみましょう。numpyのarangeというメソッドを使います。

# %%
import numpy as np
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# **欠損値を知ろう（この説明は将来より適切な場所に移動する）**
# <br>データの一部が「（記録ミス・紛失等の理由で）値がない」場合、欠損値（missing values）といいます。たとえば、一郎・花子・二郎の国語のテストをしたとき、二郎のテストの点数がわからなくなった場合、「二郎の点数が欠損値」です。
# <br>Pythonでは欠損値をNaNと表します。
#
# > 「え？欠損値って重要なの？それをNaNで表すことって大切なことなの？」と思う人もいるかも知れませんが、現実の世界では「データを取り損ねる（もしくはデータは取ったけどなくなってしまった）」ということはよくあり、「欠損値をどう表すか」を知っておくことは大切です。

# %% [markdown]
# **お疲れさまでした**
# <br>
# 皆さん、お疲れさまでした。今日の「Pythonの第一歩」はこれで終わりです。
# 「案外かんたんだった」、「いや、難しかった」、人によっていろいろな感想があると思いますが、「Excelを使った回帰分析以外の方法」を勉強してみたいという人はぜひ「[Pythonを使った単回帰](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_2_ols.ipynb)」にもチャレンジしてみてください。
