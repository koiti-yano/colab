# %% [markdown]
# #**Python入門（その1-1）：Pythonのライブラリは役に立つ！**
#
# このColabのノートブック「Python入門（その1-1）」では「Pythonでのライブラリの有用性」について解説します。
# すでに「[Python入門（その1）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_1_basic.ipynb)」を読んでいることを前提に説明します。
#
# > 注：このノートブックは駒澤大学経済学部で開講している「経済統計a/b」「応用マクロ経済学a/b」で履修生に**最低限の知識**だけ解説する**補助資料**です

# %% [markdown]
# **平方根を計算しよう！**
#
# 平方根を計算することを考えましょう。たとえば、4の平方根は2です。つまり、
# $$\sqrt{4}=2$$
# ですね。たとえば、Excelの場合=sqrt(4)と入力すれば、平方根を計算できます（平方根を英語でsquare rootといい、sqrt()という関数名は英語に由来します）。
#
# Pythonでも試してみましょう。

# %%
sqrt(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-317e033d29d5> in <cell line: 1>()
# ----> 1 sqrt(4)
#
# NameError: name 'sqrt' is not defined

# %% [markdown]
# おや？NameErrorという文字が出てきました。どうやらうまく計算できなかったようです。どうしたらいいでしょうか？
#
# 実はPythonで平方根を計算するためにはライブラリというものを読み込む（importする）必要があります。
#
# sqrt()という関数はNumPyという数値計算を効率的に行うライブラリに含まれています。
#
# Python初心者は「ライブラリ？import?なにそれ？」と思う人が実際にそうなるのか試してみましょう。

# %%
import numpy # importは「取り込む」という意味です。
numpy.sqrt(4) # .ピリオドを使ってmath内にあるsqrt()を呼び出します
# Out:
# 2.0

# %% [markdown]
# ところでメソッドsqrt()を使うとき、「numpy.sqrt(4)」と入力してもいいのですが、もう少し短く書きたいという人もいるかもしれません。その場合、asというコマンドを使って短くすることができます。numplyをnpと短くして使ってみましょう。
# <br>
# 以下のように書きます。

# %%
import numpy as np # numpyをnpという名前で呼び出します。ちょっと英語っぽい
np.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# **Pythonではライブラリ（パッケージ）を活用しよう！**
#
# Pythonには、NumPy以外にもデータの取扱が便利になるpandas、グラフ作成に役立つmatplotlib、回帰分析のstatsmodels.api、機械学習のscikit-learn(sklearn)など多くの役立つライブラリがあります。

# %%
# 最初に重要な呪文を唱えます。
# 初心者の間は何をしているのかわからなくても構いません。
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
# 注釈：statsmodelsのメソッドを使う場合は、以下のように
# statsmodels.apiのimportが必要となります。
# import statsmodels.api as sm
print(sm.__version__)
# Out:
# 0.13.5

# %% [markdown]
# **最後に一言**
#
# 今日はPythonで回帰（単回帰）を実行する方法を解説しました。
#
# 「気温が上がると、アイスクリームへの支出が増える」というのは常識的な関係ですが、「人口成長率が低下すると、物質的な豊かさが向上する」というのはちょっと意外な関係だったかもしれません。
#
# データ分析（実証分析）をしていると、このように「ちょっと意外な関係」を見つけることがあり、その辺りが「データ分析が面白い」点ではないかと（個人的には）考えています。
