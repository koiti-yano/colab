# %% [markdown]
# # **Pythonでプログラミング演習（目次）**
#
# **はじめに：**<br>
# 最初に「colaboratoryで始めるpython.pdf」を読んで、Colab（Google Colaboratory）を準備してから以下を読んでください。
# <br>
# <br>
#
# ---
# このノートブックは「Pythonでプログラミング演習」の目次です。
#
# *   [Pythonでプログラミング演習（その1）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python/python_stats_intro_01_basic.ipynb)：Pythonの第一歩
# *   [Pythonでプログラミング演習（その2）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python/python_stats_intro_01-2_lib.ipynb)：Pythonとライブラリ
# * [Pythonでプログラミング演習（寄り道）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/game/text_adventure_game_python.ipynb)：Pythonで作る「1分で終わるテキスト・アドベンチャー・ゲーム」
# * [Pythonでプログラミング演習（その3）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python/python_stats_intro_07_for.ipynb)：Pythonでif・for・whileを使う
# * [Pythonでプログラミング演習（寄り道その2）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/webAPI_usage/郵便番号_json_python.ipynb)：郵便番号から住所を取得しよう！
# * [Pythonでプログラミング演習（その4）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python/python_stats_intro_08_def.ipynb)：Pythonで関数定義
#
# > 注：このノートブックは駒澤大学経済学部で開講している「応用マクロ経済学a/b」と「経済統計a/b」で「Excel以外の手法を学ぶ意欲がある履修生向け」にPythonの最低限の知識を解説する補助資料です。
#
# <br>
#
# [参考：一般向け]
# * [Pythonプログラミング入門（東京大学 数理・情報教育研究センター）](https://utokyo-ipp.github.io/)
# * [Python 入門](https://tutorials.chainer.org/ja/index.html) ：ChainerチュートリアルにあるPython入門
# * [ゼロからのPython入門講座](https://www.python.jp/train/index.html)：Python JapanにあるPython入門<br>
# * [Python公式ドキュメント](https://docs.python.org/ja/3.9/contents.html)
# （読みやすいわけではありませんが、公式ドキュメントが一番正確です。困ったら読んでみましょう）
#
#
# [参考：経済学部生向け]
# * [中妻照雄先生『Pythonによる計量経済学入門』（朝倉書店, 2020）](https://github.com/nakatsuma/python_for_econometrics)
# * [春山鉄源先生『Pythonで学ぶ入門計量経済学』](https://py4etrics.github.io/index.html)
# * [原泰史先生『Python による経済・経営分析のためのデータサイエンス』 (東京図書, 2021) ](https://sites.google.com/view/yasushihara)
