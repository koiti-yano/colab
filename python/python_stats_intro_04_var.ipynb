# %% [markdown]
# **平均・分散・標準偏差**
#
# statisticsを使って平均・分散・標準偏差の計算をします。
#
#
# > 以下のサイトを参考にしました。<br>Statistics（Python公式サイト）
# <br>
# https://docs.python.org/ja/3/library/statistics.html
# <br>
# 補足：このノートブックではstatisticsを使いましたが、pansdasやnumpyでも平均・分散・標準偏差の計算ができるので、興味がある人は検索してみてください。

# %%
# 最初にちょっと重要な呪文を唱えます。
# 最初は何をしているのかわからなくても構いません。
import statistics as st
import pandas as pd

# %% [markdown]
# 計算のため、データ（CSVファイル）をインターネットから読み込みます。ここではread_csvというメソッドを使ってインターネット上にあるデータをPythonに読み込み、ice_dataという名前で保存します。head()というメソッドはデータを上から5行表示するメソッドです。

# %%
ice_data = pd.read_csv("https://raw.githubusercontent.com/koiti-yano/colab/main/data/kion_iceCream.csv", encoding="utf_8")
ice_data.head()
# Out:
#         年月    気温  アイスクリーム支出金額
# 0  2005年4月  15.1          541
# 1  2005年5月  17.7          666
# 2  2005年6月  23.2          801
# 3  2005年7月  25.6         1033
# 4  2005年8月  28.1         1175

# %% [markdown]
# 次にデータフレームice_dataから気温とアイスクリーム支出金額を取り出してみましょう。たとえば、気温を取り出すにはice_data['気温']のように一重引用符を使います。
# <br>
# 平均にはメソッドmean(), 分散にはメソッドvariance(), 標準偏差にはメソッドstdev()を使います。

# %%
kion = ice_data['気温']
heikin = st.mean(kion)
bunsan = st.variance(kion)
hyojun = st.stdev(kion)

print(heikin)
print(bunsan)
print(hyojun)
# Out:
# 16.56
# 53.443118644067795
# 7.310480055650777
