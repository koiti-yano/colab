# %% [markdown]
# # **Pythonでデータ分析（目次）**
#
# **はじめに：**<br>
# 最初に「colaboratoryで始めるpython.pdf」を読んで、Colab（Google Colaboratory）を準備してから以下を読んでください。
# <br>
# <br>
#
# ---
# このノートブックは「Pythonでデータ分析」の目次です。
#
# *   [Pythonでデータ分析（その1）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python_stats_intro_01_basic.ipynb)：Pythonの第一歩
# *   [Pythonでデータ分析（その2）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python_stats_intro_02_ols.ipynb)：Pythonで単回帰
# *   [Pythonでデータ分析（その3）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python_stats_intro_03_matplot.ipynb)：matplotlibでグラフ作成
# * [Pythonでデータ分析（その4）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python_stats_intro_04_var.ipynb)：Pythonで平均・分散・標準偏差
# * [Pythonでデータ分析（その5）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python_stats_intro_05_ols.ipynb)：Pythonで重回帰
# * [Pythonでデータ分析（その6）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python_stats_intro_06_df.ipynb)：Pythonでデータフレームを使う（作成中）
# * [Pythonでデータ分析（その7）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python_stats_intro_07_for.ipynb)：Pythonでifとforを使う
# * [Pythonでデータ分析（その8）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python_stats_intro_08_def.ipynb)：Pythonで関数定義
# * [Pythonでデータ分析（その9）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python_stats_intro_09_pandas_plot.ipynb)：Pandasでプロット
# * [Pythonでデータ分析（その10）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/python_stats_intro_10_plotnine.ipynb)：Plotnineでプロット
#
#
# > 注：このノートブックは駒澤大学経済学部で開講している「経済統計a/b」で「Excel以外の手法を学ぶ意欲がある履修生向け」にPythonの最低限の知識を解説する補助資料です。
#
# <br>
#
# [参考：一般向け]
# * [Python 入門](https://tutorials.chainer.org/ja/index.html) ：ChainerチュートリアルにあるPython入門
# * [ゼロからのPython入門講座](https://www.python.jp/train/index.html)：Python JapanにあるPython入門<br>
# * [Python公式ドキュメント](https://docs.python.org/ja/3.9/contents.html)
# （読みやすいわけではありませんが、公式ドキュメントが一番正確です。困ったら読んでみましょう）
#
#
# [参考：経済学部生向け]
# * [中妻照雄先生『Pythonによる計量経済学入門』（朝倉書店, 2020）](https://github.com/nakatsuma/python_for_econometrics)
# * [春山鉄源先生『Pythonで学ぶ入門計量経済学』](https://py4etrics.github.io/index.html)
# * [原泰史先生『Python による経済・経営分析のためのデータサイエンス』 (東京図書, 2021) ](https://sites.google.com/view/yasushihara)
