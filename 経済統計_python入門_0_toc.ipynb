# %% [markdown]
# # **Python入門**
#
# ---
#
# [Python入門（その１）](https://colab.research.google.com/github/chainer/tutorials/blob/master/ja/02_Basics_of_Python.ipynb)：Python入門（著作権・株式会社Preferred Networks）
# <br>
# [Python入門（その２）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_1_ols.ipynb
# )：statsmodelsを使った回帰<br>
# [（参考）Chainerチュートリアル](https://tutorials.chainer.org/ja/index.html)：チュートリアル全体を読みたい人向けのリンク（著作権・株式会社Preferred Networks）
#
# > 注：このノートブックは駒澤大学経済学部で開講している「経済統計a/b」で「Excel以外の手法を学ぶ意欲がある履修生向け」にPythonの最低限の知識を解説する補助資料です。
#
# > 注：「Chainerチュートリアル」を公開してくれた株式会社Preferred Networksに感謝いたします。
