# %% [markdown]
# # **Python入門（目次）**
#
# ---
# このノートブックは「Python入門」の目次です。
#
# *   [Python入門（その1）](https://colab.research.google.com/github/chainer/tutorials/blob/master/ja/02_Basics_of_Python.ipynb)：Python入門（リンク先の著作権・株式会社Preferred Networks）
# *   [Python入門（その2）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_2_ols.ipynb
# )：Pythonで単回帰
# *   [Python入門（その3）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_3_matplot.ipynb)：matplotlibでグラフ作成
# * [Python入門（その4）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_4_var.ipynb)：Pythonで平均・分散・標準偏差
# * [Python入門（その5）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_5_ols.ipynb)：Pythonで重回帰
# *   [（参考）Chainerチュートリアル](https://tutorials.chainer.org/ja/index.html)：Chainerチュートリアル全体を読みたい人向けのリンク（リンク先の著作権・株式会社Preferred Networks）
#
# > 注：このノートブックは駒澤大学経済学部で開講している「経済統計a/b」で「Excel以外の手法を学ぶ意欲がある履修生向け」にPythonの最低限の知識を解説する補助資料です。
#
# > 注：「Chainerチュートリアル」をという大変に素晴らしいチュートリアルを公開してくれた株式会社Preferred Networksに感謝いたします。
#
#
# [参考（経済学部生向け）]
# * [春山鉄源先生『Pythonで学ぶ入門計量経済学』](https://py4etrics.github.io/index.html)
# * [原泰史先生『Python による経済・経営分析のためのデータサイエンス』 (東京図書, 2021) ](https://sites.google.com/view/yasushihara)
