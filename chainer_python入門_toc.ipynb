# %% [markdown]
# # **「Chainerチュートリアル」で学ぶPython（リンク集）**
#
# ---
#
#
#
# **このノートブックについて**<br>
# このColabのノートブックは、株式会社Preferred Networksが提供している「Chainer チュートリアル」のリンク集（目次のようなもの）です。リンク先のColabノートブックの著作権はすべて株式会社Preferred Networksが有しています。このような素晴らしいチュートリアルを公開してくれた株式会社Preferred Networksに感謝いたします。
# <br>
# *   [Python入門](https://colab.research.google.com/github/chainer/tutorials/blob/master/ja/02_Basics_of_Python.ipynb)：Pythonの基礎を解説
# *   [Pythonを使った回帰分析](https://colab.research.google.com/github/chainer/tutorials/blob/master/ja/09_Introduction_to_Scikit-learn.ipynb)：Pythonを使った回帰分析の解説
# *   [Pythonを使ったグラフ作成](https://colab.research.google.com/github/chainer/tutorials/blob/master/ja/12_Introduction_to_Matplotlib.ipynb)：Pythonを使ったグラフの作成方法
# *   [Chainerチュートリアル](https://tutorials.chainer.org/ja/index.html)：チュートリアル全体を読みたい人向けのリンク
