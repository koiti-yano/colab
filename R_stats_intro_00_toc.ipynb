# %% [markdown]
# # **Rでデータ分析入門（目次）**
#
# **はじめに：**<br>
# 最初に「colaboratoryで始めるR.pdf」を読んで、Colab（Google Colaboratory）を準備してから以下を読んでください。
# <br>
# <br>
#
#
# ---
#
#
#
# **このノートブックについて**<br>
# このColabのノートブックは「R入門」の目次です。
# <br>
# *   [R入門（その1）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/R_stats_intro_01_basic.ipynb)：Rの第一歩
# *   [R入門（その2）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/R_stats_intro_02_lm.ipynb)：Rで単回帰
# *   [R入門（その3）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/R_stats_intro_03_plot.ipynb)：Rを使ったグラフ作成
# *   [R入門（その4）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/R_stats_intro_04_var.ipynb)：Rで平均・分散・標準偏差
# *   [R入門（その5）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/R_stats_intro_05_lm.ipynb)：Rで重回帰
# *   [R入門（その6）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/R_stats_intro_06_df.ipynb)：data.frame(or tibble)とdplyr
# *   [R入門（その7）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/R_stats_intro_07_for.ipynb)：Rの制御構文（ifとfor）
# *   [R入門（その8）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/R_stats_intro_08_func.ipynb)：Rで関数を作る
# *   [R入門（その9）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/R_stats_intro_09_dummy.ipynb)：Rでダミー変数
# *   [R入門（その10）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/R_stats_intro_10_pipe.ipynb)：Rでパイプ演算子とplaceholder
# *   [R入門（その11）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/R_stats_intro_11_ggplot2.ipynb)：ggplot2の基礎
#
#
#
# > 注：このノートブックは駒澤大学経済学部で開講している「経済統計a/b」で「Excel以外の手法を学ぶ意欲がある履修生向け」に統計解析ソフトRの最低限の知識を解説する補助資料です。
#
# [参考]
# *   [Introduction to Econometrics with R](https://www.econometrics-with-r.org/)
# *   リスト項目
