# %%
a = 1

# %% [markdown]
# **Pythonを学ぶ**
# <br>Pythonについては多くの優れた入門書がありますので、皆さん自身にあったものを探してみてください。
# <br>でも、「いきなり本を買うのはちょっと・・・」という人もいるかも知れません。そういう人は以下の「Python入門」にチャレンジしてみてください。（上から順番にやってみてください。）
# <br>https://colab.research.google.com/github/chainer/tutorials/blob/master/ja/02_Basics_of_Python.ipynb
# <br>
# https://colab.research.google.com/github/chainer/tutorials/blob/master/ja/09_Introduction_to_Scikit-learn.ipynb
# <br>
# https://colab.research.google.com/github/chainer/tutorials/blob/master/ja/11_Introduction_to_Pandas.ipynb
# <br>
# https://colab.research.google.com/github/chainer/tutorials/blob/master/ja/12_Introduction_to_Matplotlib.ipynb
