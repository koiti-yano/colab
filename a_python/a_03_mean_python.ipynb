# %% [markdown]
# #**Pythonで平均・中央値を計算する**
#
# 経済統計a第3回で学んだ平均値・中央値をPythonで計算する方法を説明します。
# <br>
# このノートブックで説明するのは、「Pandasというモジュールにあるmean()とmedian()というメソッド」を使う方法です。
#
# なお、このノートブックは「[Pythonの第一歩](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_1_basic.ipynb)」をすでに読んでいることを前提にしています。
#
#
# > 授業の裏話：Pythonでは平均値・中央値を計算する方法としてはモジュールstatisticsを使ったり、モジュールnumpyを使ったりと複数の方法があります。
#
# **参考文献**
# <br>
# https://pandas.pydata.org/docs/reference/frame.html
# <br>
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html#pandas.DataFrame.mean
# <br>
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.median.html#pandas.DataFrame.median

# %%
# 最初に重要な呪文を唱えます。
# pandasというモジュールをpdという名前で読み込みます。
import pandas as pd
#import statistics as st

# %% [markdown]
# 授業で何度も使った「小さな町の世帯年収」のデータをインターネット（dropbox）からダウンロードします。
# <br>
# Pandasのメソッドであるread_csv()を使って、incomesという変数に代入します。head()は最初の5行を表示するメソッドです。

# %%
incomes = pd.read_csv("https://www.dropbox.com/s/b1m49lng82mt779/incomes_in_a_small_town.csv?raw=1",encoding="utf_8")
incomes.head()
# Out:
#    income
# 0    1258
# 1   13674
# 2   21946
# 3    8763
# 4    3673

# %% [markdown]
# まず、平均を計算します。mean()というメソッドを使います。
#
# > meanというのは平均を意味する英語です（averageでない点に注意してください）

# %%
incomes.mean()
# Out:
# income    12806.058824
# dtype: float64

# %% [markdown]
# 次は中央値です。median()というメソッドを使います。

# %%
incomes.median()
# Out:
# income    13151.5
# dtype: float64

# %% [markdown]
# 平均も中央値も簡単ですね。
