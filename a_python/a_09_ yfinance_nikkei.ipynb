# %%
#!pip install yfinance #不要
import yfinance as yf

# %%
# 銘柄名（会社名や株価指数名）
#namae = "^N225" #日経平均株価指数
namae = "SONY" # ソニー

# 株価データもしくは株価指数のダウンロード
kabuka = yf.download(namae, start="2024-01-01")

# 表示
kabuka.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2024-05-24  80.180000  80.779999  80.150002  80.290001  80.290001   740000
# 2024-05-28  80.540001  80.769997  79.769997  79.870003  79.870003   539400
# 2024-05-29  78.989998  79.370003  78.339996  78.449997  78.449997   758500
# 2024-05-30  80.480003  81.260002  80.150002  80.790001  80.790001  1019500
# 2024-05-31  81.750000  82.379997  81.470001  82.339996  82.339996   968200

# %%
kabuka["Adj Close"].plot()
# Out:
# <Axes: xlabel='Date'>
