# %%
a <- 1
b <- 2
a + b
# Out:
# [1] 3

# %% [markdown]
# **Rを学ぶ**
# <br>Rについては優れた入門書がいろいろと出版されています。たとえば以下の書籍『R言語ではじめるプログラミングとデータ分析』を見てください（紹介した書籍以外にも素晴らしいRの入門書は多くありますので、探してみてください。）<br>https://www.amazon.co.jp/dp/4802612389/
# <br>でも、「いきなり本を買うのはちょっと・・・」という人もいるかも知れません。授業のサイトで「経済統計a_R入門.ipynb」というノートブックを配布しているので、まずはそちらにチャレンジしてみてください。
