# %% [markdown]
# #**Rで気象庁のWebAPIを使う**
# スマホのアプリで今日の天気や明日の天気を見たことがある人もいるかと思います。スマホのアプリは（基本的には）気象情報会社から提供される情報をネットから取ってきて表示しています。
#
# 実際の仕組みとは少し違うかもしれませんが、Rとjsonliteを使って気象庁のWeb API（気象庁はWeb APIと呼んでいないようですが）から今日・明日・明後日の天気予報を取得し、表示することを考えてみましょう。
#
# **参考**
# <br>
# Getting started with JSON and jsonlite
# <br>
# https://cran.r-project.org/web/packages/jsonlite/vignettes/json-aaquickstart.html<br>
# オープンデータとWeb API（奥村晴彦先生）<br>
# https://okumuralab.org/~okumura/stat/webapi.html
# <br>
# JSONとは（Oracle）
# <br>
# https://www.oracle.com/jp/database/what-is-json/

# %%
rm(list=ls())

# %% [markdown]
# 注：jsonliteはColabに元々インストールされているためinstall.packages()は不要です。

# %%
library(jsonlite)

# %%
# 東京
area_index <- 130000
forecast_url <- paste("https://www.jma.go.jp/bosai/forecast/data/forecast/", area_index, ".json", sep="")
forecast_url
# Out:
# [1] "https://www.jma.go.jp/bosai/forecast/data/forecast/130000.json"

# %%
forecast_jma = fromJSON(forecast_url)
#forecast_jma = read_json(forecast_url, simplifyVector = TRUE)
forecast_jma |> class()
# Out:
# [1] "data.frame"

# %%
names(forecast_jma)
# Out:
# [1] "publishingOffice" "reportDatetime"   "timeSeries"       "tempAverage"
# [5] "precipAverage"

# %% [markdown]
# 気象庁Web APIから返ってきたforecast_jmaは少し複雑な構造をしているため、str()を使ってその構造を確認します。

# %%
forecast_jma |> str()
# str()以外のJSON解読の仕方
# Rstudio上で以下の通りView()を実行（Viewは便利）
# forecast_jma$timeSeries |> View()
# forecast_jma$timeSeriesが表示されるため、あとは自分がほしい
# データまでクリックして確認する。
# Out:
# 'data.frame':	2 obs. of  5 variables:
#  $ publishingOffice: chr  "気象庁" "気象庁"
#  $ reportDatetime  : chr  "2022-07-14T17:00:00+09:00" "2022-07-14T17:00:00+09:00"
#  $ timeSeries      :List of 2
#   ..$ :'data.frame':	3 obs. of  2 variables:
#   .. ..$ timeDefines:List of 3
#   .. .. ..$ : chr  "2022-07-14T17:00:00+09:00" "2022-07-15T00:00:00+09:00" "2022-07-16T00:00:00+09:00"
#   .. .. ..$ : chr  "2022-07-14T18:00:00+09:00" "2022-07-15T00:00:00+09:00" "2022-07-15T06:00:00+09:00" "2022-07-15T12:00:00+09:00" ...
#   .. .. ..$ : chr  "2022-07-15T00:00:00+09:00" "2022-07-15T09:00:00+09:00"
#   .. ..$ areas      :List of 3
#   .. .. ..$ :'data.frame':	4 obs. of  5 variables:
#   .. .. .. ..$ area        :'data.frame':	4 obs. of  2 variables:
#   .. .. .. .. ..$ name: chr  "東京地方" "伊豆諸島北部" "伊豆諸島南部" "小笠原諸島"
#   .. .. .. .. ..$ code: chr  "130010" "130020" "130030" "130040"
#   .. .. .. ..$ weatherCodes:List of 4
#   .. .. .. .. ..$ : chr  "300" "203" "202"
#   .. .. .. .. ..$ : chr  "214" "203" "203"
#   .. .. .. .. ..$ : chr  "203" "203" "203"
#   .. .. .. .. ..$ : chr  "200" "200" "200"
#   .. .. .. ..$ weathers    :List of 4
#   .. .. .. .. ..$ : chr  "雨" "くもり　時々　雨　所により　夕方　から　雷を伴い　激しく　降る" "くもり　一時　雨"
#   .. .. .. .. ..$ : chr  "くもり　夜遅く　雨" "くもり　時々　雨　所により　昼前　から　昼過ぎ　雷を伴い　激しく　降る" "くもり　時々　雨"
#   .. .. .. .. ..$ : chr  "くもり　夜のはじめ頃　雨" "くもり　時々　雨　所により　昼前　から　昼過ぎ　雷を伴い　激しく　降る" "くもり　時々　雨"
#   .. .. .. .. ..$ : chr  "くもり　所により　雨　で　雷を伴う" "くもり　所により　雨" "くもり"
#   .. .. .. ..$ winds       :List of 4
#   .. .. .. .. ..$ : chr  "南東の風" "南の風" "南の風　後　南西の風　やや強く"
#   .. .. .. .. ..$ : chr  "東の風" "南の風" "南の風　後　南西の風　やや強く"
#   .. .. .. .. ..$ : chr  "西の風　後　南西の風" "南の風　後　南西の風　やや強く" "南西の風　後　やや強く"
#   .. .. .. .. ..$ : chr  "南西の風" "南西の風" "南西の風"
#   .. .. .. ..$ waves       :List of 4
#   .. .. .. .. ..$ : chr  "０．５メートル" "０．５メートル" "０．５メートル　後　１メートル"
#   .. .. .. .. ..$ : chr  "１．５メートル" "１．５メートル" "１．５メートル　後　２．５メートル　ただし　新島　では　１．５メートル　後　３メートル"
#   .. .. .. .. ..$ : chr  "１．５メートル" "１．５メートル　後　２メートル　ただし　三宅島　では　１．５メートル" "２メートル　後　３メートル"
#   .. .. .. .. ..$ : chr  "１．５メートル" "１．５メートル" "１．５メートル　後　２メートル"
#   .. .. ..$ :'data.frame':	4 obs. of  2 variables:
#   .. .. .. ..$ area:'data.frame':	4 obs. of  2 variables:
#   .. .. .. .. ..$ name: chr  "東京地方" "伊豆諸島北部" "伊豆諸島南部" "小笠原諸島"
#   .. .. .. .. ..$ code: chr  "130010" "130020" "130030" "130040"
#   .. .. .. ..$ pops:List of 4
#   .. .. .. .. ..$ : chr  "60" "60" "50" "50" ...
#   .. .. .. .. ..$ : chr  "50" "60" "70" "50" ...
#   .. .. .. .. ..$ : chr  "50" "50" "60" "50" ...
#   .. .. .. .. ..$ : chr  "40" "40" "40" "40" ...
#   .. .. ..$ :'data.frame':	4 obs. of  2 variables:
#   .. .. .. ..$ area :'data.frame':	4 obs. of  2 variables:
#   .. .. .. .. ..$ name: chr  "東京" "大島" "八丈島" "父島"
#   .. .. .. .. ..$ code: chr  "44132" "44172" "44263" "44301"
#   .. .. .. ..$ temps:List of 4
#   .. .. .. .. ..$ : chr  "23" "27"
#   .. .. .. .. ..$ : chr  "22" "29"
#   .. .. .. .. ..$ : chr  "23" "27"
#   .. .. .. .. ..$ : chr  "27" "30"
#   ..$ :'data.frame':	2 obs. of  2 variables:
#   .. ..$ timeDefines:List of 2
#   .. .. ..$ : chr  "2022-07-15T00:00:00+09:00" "2022-07-16T00:00:00+09:00" "2022-07-17T00:00:00+09:00" "2022-07-18T00:00:00+09:00" ...
#   .. .. ..$ : chr  "2022-07-15T00:00:00+09:00" "2022-07-16T00:00:00+09:00" "2022-07-17T00:00:00+09:00" "2022-07-18T00:00:00+09:00" ...
#   .. ..$ areas      :List of 2
#   .. .. ..$ :'data.frame':	3 obs. of  4 variables:
#   .. .. .. ..$ area         :'data.frame':	3 obs. of  2 variables:
#   .. .. .. .. ..$ name: chr  "東京地方" "伊豆諸島" "小笠原諸島"
#   .. .. .. .. ..$ code: chr  "130010" "130100" "130040"
#   .. .. .. ..$ weatherCodes :List of 3
#   .. .. .. .. ..$ : chr  "203" "202" "202" "201" ...
#   .. .. .. .. ..$ : chr  "203" "203" "202" "201" ...
#   .. .. .. .. ..$ : chr  "200" "200" "200" "201" ...
#   .. .. .. ..$ pops         :List of 3
#   .. .. .. .. ..$ : chr  "" "50" "50" "40" ...
#   .. .. .. .. ..$ : chr  "" "80" "60" "40" ...
#   .. .. .. .. ..$ : chr  "" "40" "40" "30" ...
#   .. .. .. ..$ reliabilities:List of 3
#   .. .. .. .. ..$ : chr  "" "" "C" "B" ...
#   .. .. .. .. ..$ : chr  "" "" "C" "B" ...
#   .. .. .. .. ..$ : chr  "" "" "C" "A" ...
#   .. .. ..$ :'data.frame':	3 obs. of  7 variables:
#   .. .. .. ..$ area         :'data.frame':	3 obs. of  2 variables:
#   .. .. .. .. ..$ name: chr  "東京" "八丈島" "父島"
#   .. .. .. .. ..$ code: chr  "44132" "44263" "44301"
#   .. .. .. ..$ tempsMin     :List of 3
#   .. .. .. .. ..$ : chr  "" "24" "24" "24" ...
#   .. .. .. .. ..$ : chr  "" "25" "25" "26" ...
#   .. .. .. .. ..$ : chr  "" "28" "28" "28" ...
#   .. .. .. ..$ tempsMinUpper:List of 3
#   .. .. .. .. ..$ : chr  "" "26" "25" "26" ...
#   .. .. .. .. ..$ : chr  "" "26" "27" "27" ...
#   .. .. .. .. ..$ : chr  "" "29" "29" "30" ...
#   .. .. .. ..$ tempsMinLower:List of 3
#   .. .. .. .. ..$ : chr  "" "22" "22" "23" ...
#   .. .. .. .. ..$ : chr  "" "23" "24" "25" ...
#   .. .. .. .. ..$ : chr  "" "26" "27" "27" ...
#   .. .. .. ..$ tempsMax     :List of 3
#   .. .. .. .. ..$ : chr  "" "29" "32" "34" ...
#   .. .. .. .. ..$ : chr  "" "27" "28" "29" ...
#   .. .. .. .. ..$ : chr  "" "30" "31" "31" ...
#   .. .. .. ..$ tempsMaxUpper:List of 3
#   .. .. .. .. ..$ : chr  "" "31" "34" "37" ...
#   .. .. .. .. ..$ : chr  "" "29" "30" "30" ...
#   .. .. .. .. ..$ : chr  "" "31" "32" "33" ...
#   .. .. .. ..$ tempsMaxLower:List of 3
#   .. .. .. .. ..$ : chr  "" "26" "30" "32" ...
#   .. .. .. .. ..$ : chr  "" "26" "26" "27" ...
#   .. .. .. .. ..$ : chr  "" "29" "30" "30" ...
#  $ tempAverage     :'data.frame':	2 obs. of  1 variable:
#   ..$ areas:List of 2
#   .. ..$ : NULL
#   .. ..$ :'data.frame':	3 obs. of  3 variables:
#   .. .. ..$ area:'data.frame':	3 obs. of  2 variables:
#   .. .. .. ..$ name: chr  "東京" "八丈島" "父島"
#   .. .. .. ..$ code: chr  "44132" "44263" "44301"
#   .. .. ..$ min : chr  "22.6" "23.4" "25.7"
#   .. .. ..$ max : chr  "30.0" "28.1" "30.4"
#  $ precipAverage   :'data.frame':	2 obs. of  1 variable:
#   ..$ areas:List of 2
#   .. ..$ : NULL
#   .. ..$ :'data.frame':	3 obs. of  3 variables:
#   .. .. ..$ area:'data.frame':	3 obs. of  2 variables:
#   .. .. .. ..$ name: chr  "東京" "八丈島" "父島"
#   .. .. .. ..$ code: chr  "44132" "44263" "44301"
#   .. .. ..$ min : chr  "8.1" "7.0" "3.5"
#   .. .. ..$ max : chr  "40.7" "41.5" "17.7"

# %%
area_name <- forecast_jma$timeSeries[[1]]$areas[[1]]$area$name[1]

cat(area_name, "の天気\n", sep="")
# 今日の天気
cat("今日の天気：", forecast_jma$timeSeries[[1]]$areas[[1]]$weathers[[1]][[1]],"\n")

# 明日の天気
cat("明日の天気：", forecast_jma$timeSeries[[1]]$areas[[1]]$weathers[[1]][[2]],"\n")

# 明後日の天気
cat("明後日の天気：",forecast_jma$timeSeries[[1]]$areas[[1]]$weathers[[1]][[3]],"\n")
# Out:
# 東京地方の天気
# 今日の天気： 雨　所により　雷を伴い　激しく　降る
# 明日の天気： くもり　未明　雨　多摩西部　では　昼過ぎ　から　夜のはじめ頃　雷を伴い　激しく　降る
# 明後日の天気： くもり　時々　晴れ
