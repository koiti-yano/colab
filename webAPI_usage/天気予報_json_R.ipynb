# %% [markdown]
# #**Rで気象庁のWebAPIを使う**
#
# Rとjsonliteを使って気象庁のWeb API（気象庁はWeb APIと呼んでいないようですが）から今日・明日・明後日の天気予報を取得し、表示することを考えてみましょう。
#
# **参考**
# <br>
# オープンデータとWeb API（奥村晴彦先生）<br>
# https://okumuralab.org/~okumura/stat/webapi.html

# %%
rm(list=ls())

# %% [markdown]
# 注：jsonliteはColabに元々インストールされているためinstall.packages()は不要です。

# %%
library(jsonlite)

# %%
# 東京
area_index <- 130000
forecast_url <- paste("https://www.jma.go.jp/bosai/forecast/data/forecast/", area_index, ".json", sep="")
forecast_url
# Out:
# [1] "https://www.jma.go.jp/bosai/forecast/data/forecast/130000.json"

# %%
forecast_jma = read_json(forecast_url, simplifyVector = TRUE)

area_name <- forecast_jma$timeSeries[[1]]$areas[[1]]$area$name[1]

cat(area_name, "の天気\n", sep="")
# 今日の天気
cat("今日の天気：", forecast_jma$timeSeries[[1]]$areas[[1]]$weathers[[1]][[1]],"\n")

# 明日の天気
cat("明日の天気：", forecast_jma$timeSeries[[1]]$areas[[1]]$weathers[[1]][[2]],"\n")

# 明後日の天気
cat("明後日の天気：",forecast_jma$timeSeries[[1]]$areas[[1]]$weathers[[1]][[3]],"\n")
# Out:
# 東京地方の天気
# 今日の天気： 晴れ　夜のはじめ頃　くもり　所により　夜のはじめ頃　まで　雨　で　雷を伴う
# 明日の天気： くもり　昼前　から　昼過ぎ　晴れ　多摩西部　では　夜のはじめ頃　雨　で　雷を伴い　激しく　降る
# 明後日の天気： くもり　後　一時　雨

# %%
names(forecast_jma)
# Out:
# [1] "publishingOffice" "reportDatetime"   "timeSeries"       "tempAverage"
# [5] "precipAverage"

# %%
forecast_jma |> str()

# str()以外のJSON解読の仕方
# Rstudio上で以下の通りView()を実行（Viewは便利）
# forecast_jma$timeSeries |> View()
# forecast_jma$timeSeriesが表示されるため、あとは自分がほしい
# データまでクリックして確認する。
# Out:
# 'data.frame':	2 obs. of  5 variables:
#  $ publishingOffice: chr  "気象庁" "気象庁"
#  $ reportDatetime  : chr  "2022-07-10T17:00:00+09:00" "2022-07-10T17:00:00+09:00"
#  $ timeSeries      :List of 2
#   ..$ :'data.frame':	3 obs. of  2 variables:
#   .. ..$ timeDefines:List of 3
#   .. .. ..$ : chr  "2022-07-10T17:00:00+09:00" "2022-07-11T00:00:00+09:00" "2022-07-12T00:00:00+09:00"
#   .. .. ..$ : chr  "2022-07-10T18:00:00+09:00" "2022-07-11T00:00:00+09:00" "2022-07-11T06:00:00+09:00" "2022-07-11T12:00:00+09:00" ...
#   .. .. ..$ : chr  "2022-07-11T00:00:00+09:00" "2022-07-11T09:00:00+09:00"
#   .. ..$ areas      :List of 3
#   .. .. ..$ :'data.frame':	4 obs. of  5 variables:
#   .. .. .. ..$ area        :'data.frame':	4 obs. of  2 variables:
#   .. .. .. .. ..$ name: chr  "東京地方" "伊豆諸島北部" "伊豆諸島南部" "小笠原諸島"
#   .. .. .. .. ..$ code: chr  "130010" "130020" "130030" "130040"
#   .. .. .. ..$ weatherCodes:List of 4
#   .. .. .. .. ..$ : chr  "101" "200" "212"
#   .. .. .. .. ..$ : chr  "111" "211" "212"
#   .. .. .. .. ..$ : chr  "111" "101" "201"
#   .. .. .. .. ..$ : chr  "214" "203" "202"
#   .. .. .. ..$ weathers    :List of 4
#   .. .. .. .. ..$ : chr  "晴れ　夜のはじめ頃　くもり　所により　夜のはじめ頃　まで　雨　で　雷を伴う" "くもり　昼前　から　昼過ぎ　晴れ　多摩西部　では　夜のはじめ頃　雨　で　雷を伴い　激しく　降る" "くもり　後　一時　雨"
#   .. .. .. .. ..$ : chr  "晴れ　夜　くもり　所により　夜遅く　霧" "くもり　昼過ぎ　から　晴れ　所により　昼前　まで　霧" "くもり　後　一時　雨"
#   .. .. .. .. ..$ : chr  "晴れ　夜　くもり　三宅島　では　夜遅く　霧" "晴れ　朝晩　くもり　三宅島　では　昼前　まで　霧" "くもり　時々　晴れ"
#   .. .. .. .. ..$ : chr  "くもり　夜遅く　雨　所により　雷　を伴う" "くもり　昼過ぎ　まで　時々　雨　所により　夕方　まで　雷　を伴う" "くもり　一時　雨"
#   .. .. .. ..$ winds       :List of 4
#   .. .. .. .. ..$ : chr  "南の風　２３区西部　では　はじめ　南の風　やや強く" "南の風" "北東の風　後　南東の風"
#   .. .. .. .. ..$ : chr  "南の風" "北東の風　後　東の風" "北東の風　後　南の風"
#   .. .. .. .. ..$ : chr  "南東の風" "東の風" "東の風　後　南東の風"
#   .. .. .. .. ..$ : chr  "南西の風　やや強く" "南西の風　やや強く" "南西の風"
#   .. .. .. ..$ waves       :List of 4
#   .. .. .. .. ..$ : chr  "１メートル　後　０．５メートル" "０．５メートル" "０．５メートル"
#   .. .. .. .. ..$ : chr  "１．５メートル" "１．５メートル" "１．５メートル"
#   .. .. .. .. ..$ : chr  "１．５メートル" "１．５メートル" "１．５メートル"
#   .. .. .. .. ..$ : chr  "２メートル" "２メートル" "１．５メートル"
#   .. .. ..$ :'data.frame':	4 obs. of  2 variables:
#   .. .. .. ..$ area:'data.frame':	4 obs. of  2 variables:
#   .. .. .. .. ..$ name: chr  "東京地方" "伊豆諸島北部" "伊豆諸島南部" "小笠原諸島"
#   .. .. .. .. ..$ code: chr  "130010" "130020" "130030" "130040"
#   .. .. .. ..$ pops:List of 4
#   .. .. .. .. ..$ : chr  "10" "10" "20" "20" ...
#   .. .. .. .. ..$ : chr  "10" "10" "10" "10" ...
#   .. .. .. .. ..$ : chr  "10" "10" "10" "10" ...
#   .. .. .. .. ..$ : chr  "60" "60" "60" "50" ...
#   .. .. ..$ :'data.frame':	4 obs. of  2 variables:
#   .. .. .. ..$ area :'data.frame':	4 obs. of  2 variables:
#   .. .. .. .. ..$ name: chr  "東京" "大島" "八丈島" "父島"
#   .. .. .. .. ..$ code: chr  "44132" "44172" "44263" "44301"
#   .. .. .. ..$ temps:List of 4
#   .. .. .. .. ..$ : chr  "24" "33"
#   .. .. .. .. ..$ : chr  "23" "31"
#   .. .. .. .. ..$ : chr  "23" "30"
#   .. .. .. .. ..$ : chr  "26" "30"
#   ..$ :'data.frame':	2 obs. of  2 variables:
#   .. ..$ timeDefines:List of 2
#   .. .. ..$ : chr  "2022-07-11T00:00:00+09:00" "2022-07-12T00:00:00+09:00" "2022-07-13T00:00:00+09:00" "2022-07-14T00:00:00+09:00" ...
#   .. .. ..$ : chr  "2022-07-11T00:00:00+09:00" "2022-07-12T00:00:00+09:00" "2022-07-13T00:00:00+09:00" "2022-07-14T00:00:00+09:00" ...
#   .. ..$ areas      :List of 2
#   .. .. ..$ :'data.frame':	3 obs. of  4 variables:
#   .. .. .. ..$ area         :'data.frame':	3 obs. of  2 variables:
#   .. .. .. .. ..$ name: chr  "東京地方" "伊豆諸島" "小笠原諸島"
#   .. .. .. .. ..$ code: chr  "130010" "130100" "130040"
#   .. .. .. ..$ weatherCodes :List of 3
#   .. .. .. .. ..$ : chr  "200" "212" "202" "200" ...
#   .. .. .. .. ..$ : chr  "101" "201" "202" "201" ...
#   .. .. .. .. ..$ : chr  "203" "202" "202" "202" ...
#   .. .. .. ..$ pops         :List of 3
#   .. .. .. .. ..$ : chr  "" "50" "50" "40" ...
#   .. .. .. .. ..$ : chr  "" "40" "50" "30" ...
#   .. .. .. .. ..$ : chr  "" "50" "50" "50" ...
#   .. .. .. ..$ reliabilities:List of 3
#   .. .. .. .. ..$ : chr  "" "" "C" "C" ...
#   .. .. .. .. ..$ : chr  "" "" "C" "B" ...
#   .. .. .. .. ..$ : chr  "" "" "C" "C" ...
#   .. .. ..$ :'data.frame':	3 obs. of  7 variables:
#   .. .. .. ..$ area         :'data.frame':	3 obs. of  2 variables:
#   .. .. .. .. ..$ name: chr  "東京" "八丈島" "父島"
#   .. .. .. .. ..$ code: chr  "44132" "44263" "44301"
#   .. .. .. ..$ tempsMin     :List of 3
#   .. .. .. .. ..$ : chr  "" "23" "23" "23" ...
#   .. .. .. .. ..$ : chr  "" "23" "23" "23" ...
#   .. .. .. .. ..$ : chr  "" "27" "27" "27" ...
#   .. .. .. ..$ tempsMinUpper:List of 3
#   .. .. .. .. ..$ : chr  "" "25" "24" "24" ...
#   .. .. .. .. ..$ : chr  "" "25" "24" "24" ...
#   .. .. .. .. ..$ : chr  "" "29" "28" "28" ...
#   .. .. .. ..$ tempsMinLower:List of 3
#   .. .. .. .. ..$ : chr  "" "22" "22" "21" ...
#   .. .. .. .. ..$ : chr  "" "22" "22" "21" ...
#   .. .. .. .. ..$ : chr  "" "26" "25" "25" ...
#   .. .. .. ..$ tempsMax     :List of 3
#   .. .. .. .. ..$ : chr  "" "28" "27" "29" ...
#   .. .. .. .. ..$ : chr  "" "29" "28" "28" ...
#   .. .. .. .. ..$ : chr  "" "30" "30" "30" ...
#   .. .. .. ..$ tempsMaxUpper:List of 3
#   .. .. .. .. ..$ : chr  "" "30" "31" "31" ...
#   .. .. .. .. ..$ : chr  "" "30" "29" "30" ...
#   .. .. .. .. ..$ : chr  "" "31" "32" "31" ...
#   .. .. .. ..$ tempsMaxLower:List of 3
#   .. .. .. .. ..$ : chr  "" "26" "25" "26" ...
#   .. .. .. .. ..$ : chr  "" "28" "26" "27" ...
#   .. .. .. .. ..$ : chr  "" "29" "29" "29" ...
#  $ tempAverage     :'data.frame':	2 obs. of  1 variable:
#   ..$ areas:List of 2
#   .. ..$ : NULL
#   .. ..$ :'data.frame':	3 obs. of  3 variables:
#   .. .. ..$ area:'data.frame':	3 obs. of  2 variables:
#   .. .. .. ..$ name: chr  "東京" "八丈島" "父島"
#   .. .. .. ..$ code: chr  "44132" "44263" "44301"
#   .. .. ..$ min : chr  "22.2" "23.2" "25.6"
#   .. .. ..$ max : chr  "29.7" "27.6" "30.3"
#  $ precipAverage   :'data.frame':	2 obs. of  1 variable:
#   ..$ areas:List of 2
#   .. ..$ : NULL
#   .. ..$ :'data.frame':	3 obs. of  3 variables:
#   .. .. ..$ area:'data.frame':	3 obs. of  2 variables:
#   .. .. .. ..$ name: chr  "東京" "八丈島" "父島"
#   .. .. .. ..$ code: chr  "44132" "44263" "44301"
#   .. .. ..$ min : chr  "9.3" "6.6" "2.3"
#   .. .. ..$ max : chr  "43.1" "42.8" "12.4"
