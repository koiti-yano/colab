# %% [markdown]
# #**Pythonで気象庁のWebAPIを使う**
# Pythonとrequestsを使って使って気象庁のWeb API（気象庁はWeb APIと呼んでいないようですが）から今日・明日・明後日の天気予報を取得し、表示することを考えてみましょう。
#
# **参考**
# <br>
# オープンデータとWeb API（奥村晴彦先生）
# <br>
# https://okumuralab.org/~okumura/stat/webapi.html

# %%
import requests as rq

# %%
# 東京
area_index = "130000"
forecast_url = "https://www.jma.go.jp/bosai/forecast/data/forecast/" + area_index +".json"
forecast_jma = rq.get(forecast_url).json()
print(forecast_jma)
# Out:
# [{'publishingOffice': '気象庁', 'reportDatetime': '2022-07-10T11:00:00+09:00', 'timeSeries': [{'timeDefines': ['2022-07-10T11:00:00+09:00', '2022-07-11T00:00:00+09:00', '2022-07-12T00:00:00+09:00'], 'areas': [{'area': {'name': '東京地方', 'code': '130010'}, 'weatherCodes': ['101', '200', '212'], 'weathers': ['晴れ\u3000時々\u3000くもり\u3000所により\u3000雨\u3000で\u3000雷を伴う', 'くもり\u3000昼前\u3000から\u3000昼過ぎ\u3000晴れ\u3000所により\u3000雨', 'くもり\u3000後\u3000一時\u3000雨'], 'winds': ['南の風\u3000２３区西部\u3000では\u3000南の風\u3000やや強く', '南の風', '北東の風\u3000後\u3000南東の風'], 'waves': ['１メートル\u3000後\u3000０．５メートル', '０．５メートル', '０．５メートル']}, {'area': {'name': '伊豆諸島北部', 'code': '130020'}, 'weatherCodes': ['313', '101', '212'], 'weathers': ['雨\u3000昼過ぎ\u3000から\u3000くもり', '晴れ\u3000時々\u3000くもり', 'くもり\u3000後\u3000一時\u3000雨'], 'winds': ['南の風', '北東の風\u3000後\u3000南の風', '北東の風\u3000後\u3000南の風'], 'waves': ['１．５メートル', '１．５メートル', '１．５メートル']}, {'area': {'name': '伊豆諸島南部', 'code': '130030'}, 'weatherCodes': ['200', '201', '201'], 'weathers': ['くもり\u3000所により\u3000昼過ぎ\u3000まで\u3000雨', 'くもり\u3000時々\u3000晴れ', 'くもり\u3000時々\u3000晴れ'], 'winds': ['南の風', '東の風\u3000後\u3000南東の風', '東の風\u3000後\u3000南東の風'], 'waves': ['１．５メートル', '１．５メートル', '１．５メートル']}, {'area': {'name': '小笠原諸島', 'code': '130040'}, 'weatherCodes': ['302', '203', '202'], 'weathers': ['雨\u3000時々\u3000くもり\u3000所により\u3000雷\u3000を伴う', 'くもり\u3000昼過ぎ\u3000まで\u3000時々\u3000雨\u3000所により\u3000夕方\u3000まで\u3000雷\u3000を伴う', 'くもり\u3000一時\u3000雨'], 'winds': ['南西の風\u3000やや強く', '南西の風\u3000やや強く', '南西の風'], 'waves': ['２メートル', '２メートル', '１．５メートル']}]}, {'timeDefines': ['2022-07-10T12:00:00+09:00', '2022-07-10T18:00:00+09:00', '2022-07-11T00:00:00+09:00', '2022-07-11T06:00:00+09:00', '2022-07-11T12:00:00+09:00', '2022-07-11T18:00:00+09:00'], 'areas': [{'area': {'name': '東京地方', 'code': '130010'}, 'pops': ['20', '10', '20', '10', '10', '20']}, {'area': {'name': '伊豆諸島北部', 'code': '130020'}, 'pops': ['30', '10', '10', '10', '0', '10']}, {'area': {'name': '伊豆諸島南部', 'code': '130030'}, 'pops': ['20', '10', '10', '10', '0', '10']}, {'area': {'name': '小笠原諸島', 'code': '130040'}, 'pops': ['70', '60', '60', '60', '50', '30']}]}, {'timeDefines': ['2022-07-10T09:00:00+09:00', '2022-07-10T00:00:00+09:00', '2022-07-11T00:00:00+09:00', '2022-07-11T09:00:00+09:00'], 'areas': [{'area': {'name': '東京', 'code': '44132'}, 'temps': ['32', '32', '24', '34']}, {'area': {'name': '大島', 'code': '44172'}, 'temps': ['29', '29', '23', '30']}, {'area': {'name': '八丈島', 'code': '44263'}, 'temps': ['29', '29', '23', '29']}, {'area': {'name': '父島', 'code': '44301'}, 'temps': ['31', '31', '26', '30']}]}]}, {'publishingOffice': '気象庁', 'reportDatetime': '2022-07-10T11:00:00+09:00', 'timeSeries': [{'timeDefines': ['2022-07-11T00:00:00+09:00', '2022-07-12T00:00:00+09:00', '2022-07-13T00:00:00+09:00', '2022-07-14T00:00:00+09:00', '2022-07-15T00:00:00+09:00', '2022-07-16T00:00:00+09:00', '2022-07-17T00:00:00+09:00'], 'areas': [{'area': {'name': '東京地方', 'code': '130010'}, 'weatherCodes': ['200', '212', '202', '200', '202', '202', '200'], 'pops': ['', '50', '50', '40', '50', '50', '40'], 'reliabilities': ['', '', 'C', 'C', 'C', 'C', 'C']}, {'area': {'name': '伊豆諸島', 'code': '130100'}, 'weatherCodes': ['201', '201', '202', '201', '200', '202', '202'], 'pops': ['', '40', '50', '30', '40', '50', '50'], 'reliabilities': ['', '', 'C', 'B', 'B', 'C', 'C']}, {'area': {'name': '小笠原諸島', 'code': '130040'}, 'weatherCodes': ['203', '202', '202', '202', '202', '200', '200'], 'pops': ['', '50', '50', '50', '50', '40', '40'], 'reliabilities': ['', '', 'C', 'C', 'C', 'C', 'C']}]}, {'timeDefines': ['2022-07-11T00:00:00+09:00', '2022-07-12T00:00:00+09:00', '2022-07-13T00:00:00+09:00', '2022-07-14T00:00:00+09:00', '2022-07-15T00:00:00+09:00', '2022-07-16T00:00:00+09:00', '2022-07-17T00:00:00+09:00'], 'areas': [{'area': {'name': '東京', 'code': '44132'}, 'tempsMin': ['', '23', '23', '23', '22', '24', '24'], 'tempsMinUpper': ['', '25', '24', '24', '24', '26', '26'], 'tempsMinLower': ['', '22', '22', '21', '21', '22', '22'], 'tempsMax':  ...

# %%
area_name = forecast_jma[0]['timeSeries'][0]['areas'][0]['area']['name']
print(area_name)

weathers = forecast_jma[0]['timeSeries'][0]['areas'][0]['weathers']

print("今日の天気：" + weathers[0])
print("明日の天気：" + weathers[1])
print("明後日の天気：" + weathers[2])
# Out:
# 東京地方
# 今日の天気：晴れ　時々　くもり　所により　雨　で　雷を伴う
# 明日の天気：くもり　昼前　から　昼過ぎ　晴れ　所により　雨
# 明後日の天気：くもり　後　一時　雨
