# %% [markdown]
# #**Pythonで気象庁のWebAPIを使う**
# Pythonとrequestsを使って使って気象庁のWeb API（気象庁はWeb APIと呼んでいないようですが）から今日・明日・明後日の天気予報を取得し、表示することを考えてみましょう。
#
# **参考**
# <br>
# オープンデータとWeb API（奥村晴彦先生）
# <br>
# https://okumuralab.org/~okumura/stat/webapi.html

# %%
import requests as rq

# %%
# 東京
area_index = "130000"
forecast_url = "https://www.jma.go.jp/bosai/forecast/data/forecast/" + area_index +".json"
forecast_jma = rq.get(forecast_url).json()
type(forecast_jma)
# Out:
# list

# %%
forecast_jma
# Out:
# [{'publishingOffice': '気象庁',
#   'reportDatetime': '2022-07-10T17:00:00+09:00',
#   'timeSeries': [{'areas': [{'area': {'code': '130010', 'name': '東京地方'},
#       'waves': ['１メートル\u3000後\u3000０．５メートル', '０．５メートル', '０．５メートル'],
#       'weatherCodes': ['101', '200', '212'],
#       'weathers': ['晴れ\u3000夜のはじめ頃\u3000くもり\u3000所により\u3000夜のはじめ頃\u3000まで\u3000雨\u3000で\u3000雷を伴う',
#        'くもり\u3000昼前\u3000から\u3000昼過ぎ\u3000晴れ\u3000多摩西部\u3000では\u3000夜のはじめ頃\u3000雨\u3000で\u3000雷を伴い\u3000激しく\u3000降る',
#        'くもり\u3000後\u3000一時\u3000雨'],
#       'winds': ['南の風\u3000２３区西部\u3000では\u3000はじめ\u3000南の風\u3000やや強く',
#        '南の風',
#        '北東の風\u3000後\u3000南東の風']},
#      {'area': {'code': '130020', 'name': '伊豆諸島北部'},
#       'waves': ['１．５メートル', '１．５メートル', '１．５メートル'],
#       'weatherCodes': ['111', '211', '212'],
#       'weathers': ['晴れ\u3000夜\u3000くもり\u3000所により\u3000夜遅く\u3000霧',
#        'くもり\u3000昼過ぎ\u3000から\u3000晴れ\u3000所により\u3000昼前\u3000まで\u3000霧',
#        'くもり\u3000後\u3000一時\u3000雨'],
#       'winds': ['南の風', '北東の風\u3000後\u3000東の風', '北東の風\u3000後\u3000南の風']},
#      {'area': {'code': '130030', 'name': '伊豆諸島南部'},
#       'waves': ['１．５メートル', '１．５メートル', '１．５メートル'],
#       'weatherCodes': ['111', '101', '201'],
#       'weathers': ['晴れ\u3000夜\u3000くもり\u3000三宅島\u3000では\u3000夜遅く\u3000霧',
#        '晴れ\u3000朝晩\u3000くもり\u3000三宅島\u3000では\u3000昼前\u3000まで\u3000霧',
#        'くもり\u3000時々\u3000晴れ'],
#       'winds': ['南東の風', '東の風', '東の風\u3000後\u3000南東の風']},
#      {'area': {'code': '130040', 'name': '小笠原諸島'},
#       'waves': ['２メートル', '２メートル', '１．５メートル'],
#       'weatherCodes': ['214', '203', '202'],
#       'weathers': ['くもり\u3000夜遅く\u3000雨\u3000所により\u3000雷\u3000を伴う',
#        'くもり\u3000昼過ぎ\u3000まで\u3000時々\u3000雨\u3000所により\u3000夕方\u3000まで\u3000雷\u3000を伴う',
#        'くもり\u3000一時\u3000雨'],
#       'winds': ['南西の風\u3000やや強く', '南西の風\u3000やや強く', '南西の風']}],
#     'timeDefines': ['2022-07-10T17:00:00+09:00',
#      '2022-07-11T00:00:00+09:00',
#      '2022-07-12T00:00:00+09:00']},
#    {'areas': [{'area': {'code': '130010', 'name': '東京地方'},
#       'pops': ['10', '10', '20', '20', '30']},
#      {'area': {'code': '130020', 'name': '伊豆諸島北部'},
#       'pops': ['10', '10', '10', '10', '10']},
#      {'area': {'code': '130030', 'name': '伊豆諸島南部'},
#       'pops': ['10', '10', '10', '10', '10']},
#      {'area': {'code': '130040', 'name': '小笠原諸島'},
#       'pops': ['60', '60', '60', '50', '30']}],
#     'timeDefines': ['2022-07-10T18:00:00+09:00',
#      '2022-07-11T00:00:00+09:00',
#      '2022-07-11T06:00:00+09:00',
#      '2022-07-11T12:00:00+09:00',
#      '2022-07-11T18:00:00+09:00']},
#    {'areas': [{'area': {'code': '44132', 'name': '東京'}, 'temps': ['24', '33']},
#      {'area': {'code': '44172', 'name': '大島'}, 'temps': ['23', '31']},
#      {'area': {'code': '44263', 'name': '八丈島'}, 'temps': ['23', '30']},
#      {'area': {'code': '44301', 'name': '父島'}, 'temps': ['26', '30']}],
#     'timeDefines': ['2022-07-11T00:00:00+09:00',
#      '2022-07-11T09:00:00+09:00']}]},
#  {'precipAverage': {'areas': [{'area': {'code': '44132', 'name': '東京'},
#      'max': '43.1',
#      'min': '9.3'},
#     {'area': {'code': '44263', 'name': '八丈島'}, 'max': '42.8', 'min': '6.6'},
#     {'area': {'code': '44301', 'name': '父島'}, 'max': '12.4', 'min': '2.3'}]},
#   'publishingOffice': '気象庁',
#   'reportDatetime': '2022-07-10T17:00:00+09:00',
#   'tempAverage': {'areas': [{'area': {'code': '44132', 'name': '東京'},
#      'max': '29.7',
#      'min': '22.2'},
#     {'area': {'code': '44263', 'name': '八丈島'}, 'max': '27.6', 'min': '23.2'},
#     {'area': {'code': '44301', 'name': '父島'}, 'max': '30.3', 'min': '25.6'}]},
#   'timeSeries': [{'areas': [{'area': {'code': '130010', 'name': '東京地方'},
#       'pops': ['', '50', '50', '40', '50', '50', '40'],
#       'reliabilities': ['', '', 'C', 'C', 'C', 'C', 'C'],
#       'weatherCodes': ['200', '212', '202', '200', '202', '202', '200']},
#      {'area': {'code': '130100', 'name': '伊豆諸島'},
#       'pops': ['', '40', '50', '30', '40', '50', '50'],
#       'reliabilities': ['', '', 'C', 'B', 'B', 'C', 'C'],
#       'weatherCodes': ['101', '201', '202', '201', '200', '202', '202']},
#      {'area': {'code': '130040', 'name': '小笠原諸島'},
#       'pops': ['', '50', '50', '50', '50', '40', '40'],
#       'reliabilities': ['', '', 'C', 'C', 'C', 'C', 'C'],
#       'weatherCodes': ['203', '202', '202', '202', '202', '200', '200']}],
#     'timeDefines': ['2022-07-11T00:00:00+09:00',
#      '2022-07-12T00:00:00+09:00',
#      '2022-07-13T00:00:00+09:00',
#      '2022-07-14T00:00:00+09:00',
#      '2022-07-15T00:00:00+09:00',
#      '2022-07-16T00:00:00+09:00',
#      '2022-07-17T00:00:00+09:00']},
#    {'areas': [{'area': {'code': '44132', 'name': '東京'},
#       'tempsMax': ['', '28', '27', '29', '29', '28', '32'],
#       'tempsMaxLower': ['', '26', '25', '26', '26', '25', '29'],
#       'tempsMaxUpper': ['', '30', '31', '31', '32', '31', '35'],
#       'tempsMin': ['', '23', '23', '23', '22', '24', '24'],
#       'tempsMinLower': ['', '22', '22', '21', '21', '22', '22'],
#       'tempsMinUpper': ['', '25', '24', '24', '24', '26', '26']},
#      {'area': {'code': '44263', 'name': '八丈島'},
#       'tempsMax': ['', '29', '28', '28', '29', '29', '29'],
#       'tempsMaxLower': ['', '28', '26', '27', '27', '27', '27'],
#       'tempsMaxUpper': ['', '30', '29', '30', '30', '31', '31'],
#       'tempsMin': ['', '23', '23', '23', '23', '24', '26'],
#       'tempsMinLower': ['', '22', '22', '21', '22', '23', '24'],
#       'tempsMinUpper': ['', '25', '24', '24', '25', '26', '28']},
#      {'area': {'code': '44301', 'name': '父島'},
#       'tempsMax': ['', '30', '30', '30', '30', '31', '31'],
#       'tempsMaxLower': ['', '29', '29', '29', '29', '29', '29'],
#       'tempsMaxUpper': ['', '31', '32', '31', '31', '32', '33'],
#       'tempsMin': ['', '27', '27', '27', '27', '27', '27'],
#       'tempsMinLower': ['', '26', '25', '25', '25', '26', '25'],
#       'tempsMinUpper': ['', '29', '28', '28', '29', '29', '30']}],
#     'timeDefines': ['2022-07-11T00:00:00+09:00',
#      '2022-07-12T00:00:00+09:00',
#      '2022-07-13T00:00:00+09:00',
#      '2022-07-14T00:00:00+09:00',
#      '2022-07-15T00:00:00+09:00',
#      '2022-07-16T00:00:00+09:00',
#      '2022-07-17T00:00:00+09:00']}]}]

# %%
area_name = forecast_jma[0]['timeSeries'][0]['areas'][0]['area']['name']
print(area_name)

weathers = forecast_jma[0]['timeSeries'][0]['areas'][0]['weathers']

print("今日の天気：" + weathers[0])
print("明日の天気：" + weathers[1])
print("明後日の天気：" + weathers[2])
# Out:
# 東京地方
# 今日の天気：晴れ　夜のはじめ頃　くもり　所により　夜のはじめ頃　まで　雨　で　雷を伴う
# 明日の天気：くもり　昼前　から　昼過ぎ　晴れ　多摩西部　では　夜のはじめ頃　雨　で　雷を伴い　激しく　降る
# 明後日の天気：くもり　後　一時　雨
