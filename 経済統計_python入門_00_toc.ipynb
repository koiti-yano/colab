# %% [markdown]
# # **Python入門（目次）**
#
# **はじめに：**<br>
# 最初に「colaboratoryで始めるpython.pdf」を読んで、Colab（Google Colaboratory）を準備してから以下を読んでください。
# <br>
# <br>
#
# ---
# このノートブックは「Python入門」の目次です。
#
# *   [Python入門（その1）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_01_basic.ipynb)：Pythonの第一歩
# *   [Python入門（その2）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_02_ols.ipynb
# )：Pythonで単回帰
# *   [Python入門（その3）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_03_matplot.ipynb)：matplotlibでグラフ作成
# * [Python入門（その4）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_04_var.ipynb)：Pythonで平均・分散・標準偏差
# * [Python入門（その5）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_05_ols.ipynb)：Pythonで重回帰
# * [Python入門（その6）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_06_df.ipynb)：Pythonでデータフレームを使う（作成中）
# * [Python入門（その7）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_07_for.ipynb)：Pythonでifとforを使う
# * [Python入門（その9）](https://colab.research.google.com/github/koiti-yano/colab/blob/main/経済統計_python入門_09_pandas_plot.ipynb)：Pandasでプロット
#
#
# > 注：このノートブックは駒澤大学経済学部で開講している「経済統計a/b」で「Excel以外の手法を学ぶ意欲がある履修生向け」にPythonの最低限の知識を解説する補助資料です。
#
# <br>
#
# [参考：一般向け]
# * [Python 入門](https://tutorials.chainer.org/ja/index.html) ：ChainerチュートリアルにあるPython入門
# * [ゼロからのPython入門講座](https://www.python.jp/train/index.html)：Python JapanにあるPython入門
#
# <br>
#
# [参考：経済学部生向け]
# * [中妻照雄先生『Pythonによる計量経済学入門』（朝倉書店, 2020）](https://github.com/nakatsuma/python_for_econometrics)
# * [春山鉄源先生『Pythonで学ぶ入門計量経済学』](https://py4etrics.github.io/index.html)
# * [原泰史先生『Python による経済・経営分析のためのデータサイエンス』 (東京図書, 2021) ](https://sites.google.com/view/yasushihara)
