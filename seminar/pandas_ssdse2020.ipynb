# %% [markdown]
# # **SSDSEとは？**
#
# SSDSE（教育用標準データセット）は、独立行政法人統計センターがデータ分析の素材として公開している統計データです。
# <br>
# <br>
# **公式サイト**<br>
# https://www.nstac.go.jp/SSDSE/

# %%
# 最初に重要な呪文を唱えます。
# pandasというモジュールをpdという名前で読み込みます。
import pandas as pd
#import statistics as st

# %%
# https://www.dropbox.com/s/fjycjrdmxb1az9z/SSDSE-2020A.csv?dl=0
ssdse_2020A = pd.read_csv("https://www.dropbox.com/s/fjycjrdmxb1az9z/SSDSE-2020A.csv?raw=1",encoding="utf_8", skiprows=2)
ssdse_2020A.head()
# Out:
#     地域コード 都道府県 市区町村      総人口  総人口（男）  ...   医師数  歯科医師数  薬剤師数  保育所等数  保育所等在所児数
# 0  R01100  北海道  札幌市  1952356  910614  ...  6614   2113  5398    287     26613
# 1  R01202  北海道  函館市   265979  120376  ...   801    183   680     49      3524
# 2  R01203  北海道  小樽市   121924   54985  ...   322    102   326     22      1370
# 3  R01204  北海道  旭川市   339605  156402  ...  1339    254   867     67      5715
# 4  R01205  北海道  室蘭市    88564   43143  ...   272     63   196     10      1039
#
# [5 rows x 128 columns]

# %%
# https://www.dropbox.com/s/4v0j217u44cepwc/SSDSE-2021D.csv?dl=0
ssdse_2021D = pd.read_csv("https://www.dropbox.com/s/4v0j217u44cepwc/SSDSE-2021D.csv?raw=1",encoding="utf_8", skiprows=1)
ssdse_2021D.head()
# Out:
#    男女の別   地域コード 都道府県  ...  就寝（平日の平均時刻）  出勤（有業者、平日の平均時刻）  仕事からの帰宅（有業者、平日の平均時刻）
# 0  0_総数  R01000  北海道  ...        22:56             8:27                 18:37
# 1  0_総数  R02000  青森県  ...        22:38             8:09                 18:30
# 2  0_総数  R03000  岩手県  ...        22:43             8:09                 18:24
# 3  0_総数  R04000  宮城県  ...        22:56             8:11                 18:42
# 4  0_総数  R05000  秋田県  ...        22:33             8:09                 18:19
#
# [5 rows x 122 columns]
